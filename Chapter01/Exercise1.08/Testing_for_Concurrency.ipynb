# %%
import threading
import sys; sys.setswitchinterval(10 ** -10)

class Counter:
    def __init__(self, target):
        self.value = 0
        self.target = target
        
    def update(self):
        current_value = self.value
        breakpoint()
        self.value = current_value + 1
        
    def run(self):
        threads = [threading.Thread(target=self.update)
                   for _ in range(self.target)]
        for t in threads:
            t.start()
        for t in threads:
            t.join()

# %%
import unittest

class TestCounter(unittest.TestCase):
    def setUp(self):
        self.small_params = 5
        self.med_params = 5000
        self.large_params = 10000
    
    def test_small(self):
        small_counter = Counter(self.small_params)
        small_counter.run()
        self.assertEqual(small_counter.value, self.small_params)
        
    def test_med(self):
        med_counter = Counter(self.med_params)
        med_counter.run()
        self.assertEqual(med_counter.value, self.med_params)
        
    def test_large(self):
        large_counter = Counter(self.large_params)
        large_counter.run()
        self.assertEqual(large_counter.value, self.large_params)

# %%
unittest.main(argv=[''], verbosity=2, exit=False)
# Out:
# test_large (__main__.TestCounter) ... FAIL
# test_med (__main__.TestCounter) ... FAIL
# test_small (__main__.TestCounter) ... ok
#
# ======================================================================
# FAIL: test_large (__main__.TestCounter)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-57-4ed47b9310ba>", line 22, in test_large
#     self.assertEqual(large_counter.value, self.large_params)
# AssertionError: 9996 != 10000
#
# ======================================================================
# FAIL: test_med (__main__.TestCounter)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-57-4ed47b9310ba>", line 17, in test_med
#     self.assertEqual(med_counter.value, self.med_params)
# AssertionError: 4999 != 5000
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.890s
#
# FAILED (failures=2)

# %%
sample_counter = nCounter(10)
sample_counter.run()
# Out:
# > <ipython-input-61-066f5069e308>(12)update()
# -> self.value = current_value + 1
# Exception in thread Thread-328879:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-61-066f5069e308>", line 11, in update
#     breakpoint()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 1610, in set_trace
#     pdb.set_trace(sys._getframe().f_back)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 326, in set_trace
#     self.reset()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 196, in reset
#     bdb.Bdb.reset(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 57, in reset
#     linecache.checkcache()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/compilerop.py", line 157, in check_linecache_ipython
#     linecache._checkcache_ori(*args)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/linecache.py", line 66, in checkcache
#     entry = cache[filename]
# KeyError: '<ipython-input-20-91782a3e1017>'
# Exception in thread Thread-328876:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-61-066f5069e308>", line 11, in update
#     breakpoint()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 1610, in set_trace
#     pdb.set_trace(sys._getframe().f_back)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 326, in set_trace
#     self.reset()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 196, in reset
#     bdb.Bdb.reset(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 57, in reset
#     linecache.checkcache()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/compilerop.py", line 157, in check_linecache_ipython
#     linecache._checkcache_ori(*args)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/linecache.py", line 66, in checkcache
#     entry = cache[filename]
# KeyError: '<ipython-input-29-4047ee89f2b5>'
# Exception in thread Thread-328880:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/linecache.py", line 74, in checkcache
#     stat = os.stat(fullname)
# FileNotFoundError: [Errno 2] No such file or directory: '<ipython-input-1-58721f65359e>'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-61-066f5069e308>", line 11, in update
#     breakpoint()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 1610, in set_trace
#     pdb.set_trace(sys._getframe().f_back)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 326, in set_trace
#     self.reset()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 196, in reset
#     bdb.Bdb.reset(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 57, in reset
#     linecache.checkcache()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/compilerop.py", line 157, in check_linecache_ipython
#     linecache._checkcache_ori(*args)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/linecache.py", line 76, in checkcache
#     del cache[filename]
# KeyError: '<ipython-input-1-58721f65359e>'
# Exception in thread Thread-328875:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-61-066f5069e308>", line 11, in update
#     breakpoint()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 1610, in set_trace
#     pdb.set_trace(sys._getframe().f_back)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 326, in set_trace
#     self.reset()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 196, in reset
#     bdb.Bdb.reset(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 57, in reset
#     linecache.checkcache()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/compilerop.py", line 157, in check_linecache_ipython
#     linecache._checkcache_ori(*args)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/linecache.py", line 66, in checkcache
#     entry = cache[filename]
# KeyError: '<ipython-input-32-4047ee89f2b5>'
#
#
# Exception in thread Thread-328874:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-61-066f5069e308>", line 11, in update
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 1610, in set_trace
#     pdb.set_trace(sys._getframe().f_back)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 326, in set_trace
#     self.reset()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 196, in reset
#     bdb.Bdb.reset(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 57, in reset
#     linecache.checkcache()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/compilerop.py", line 157, in check_linecache_ipython
#     linecache._checkcache_ori(*args)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/linecache.py", line 66, in checkcache
#     entry = cache[filename]
# KeyError: '<ipython-input-40-74332a430654>'
#
# Exception in thread Thread-328872:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/linecache.py", line 74, in checkcache
#     stat = os.stat(fullname)
# FileNotFoundError: [Errno 2] No such file or directory: '<ipython-input-53-a33471e3ed56>'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-61-066f5069e308>", line 11, in update
#     breakpoint()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 1610, in set_trace
#     pdb.set_trace(sys._getframe().f_back)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 326, in set_trace
#     self.reset()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 196, in reset
#     bdb.Bdb.reset(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 57, in reset
#     linecache.checkcache()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/compilerop.py", line 157, in check_linecache_ipython
#     linecache._checkcache_ori(*args)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/linecache.py", line 76, in checkcache
#     del cache[filename]
# KeyError: '<ipython-input-53-a33471e3ed56>'
# Exception in thread Thread-328877:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/linecache.py", line 74, in checkcache
#     stat = os.stat(fullname)
# FileNotFoundError: [Errno 2] No such file or directory: '<ipython-input-25-4047ee89f2b5>'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-61-066f5069e308>", line 11, in update
#     breakpoint()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 1610, in set_trace
#     pdb.set_trace(sys._getframe().f_back)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 326, in set_trace
#     self.reset()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 196, in reset
#     bdb.Bdb.reset(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 57, in reset
#     linecache.checkcache()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/compilerop.py", line 157, in check_linecache_ipython
#     linecache._checkcache_ori(*args)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/linecache.py", line 76, in checkcache
#     del cache[filename]
# KeyError: '<ipython-input-25-4047ee89f2b5>'
# Exception in thread Thread-328878:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-61-066f5069e308>", line 11, in update
#     breakpoint()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 1610, in set_trace
#     pdb.set_trace(sys._getframe().f_back)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 326, in set_trace
#     self.reset()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 196, in reset
#     bdb.Bdb.reset(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 57, in reset
#     linecache.checkcache()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/compilerop.py", line 157, in check_linecache_ipython
#     linecache._checkcache_ori(*args)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/linecache.py", line 66, in checkcache
#     entry = cache[filename]
# KeyError: '<ipython-input-54-4047ee89f2b5>'
# Exception in thread Thread-328873:
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/linecache.py", line 74, in checkcache
#     stat = os.stat(fullname)
# FileNotFoundError: [Errno 2] No such file or directory: '<ipython-input-15-de326a161aab>'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 926, in _bootstrap_inner
#     self.run()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py", line 870, in run
#     self._target(*self._args, **self._kwargs)
#   File "<ipython-input-61-066f5069e308>", line 11, in update
#     breakpoint()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 1610, in set_trace
#     pdb.set_trace(sys._getframe().f_back)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 326, in set_trace
#     self.reset()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/pdb.py", line 196, in reset
#     bdb.Bdb.reset(self)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/bdb.py", line 57, in reset
#     linecache.checkcache()
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/IPython/core/compilerop.py", line 157, in check_linecache_ipython
#     linecache._checkcache_ori(*args)
#   File "/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/linecache.py", line 76, in checkcache
#     del cache[filename]
# KeyError: '<ipython-input-15-de326a161aab>'
# (Pdb) ll
#   9  	    def update(self):
#  10  	        current_value = self.value
#  11  	        breakpoint()
#  12  ->	        self.value = current_value + 1
# (Pdb) p self.value
# 0
# (Pdb) n
# --Return--
# > <ipython-input-61-066f5069e308>(12)update()->None
# -> self.value = current_value + 1
# (Pdb) p self.value
# 1
# (Pdb) r
# > /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py(874)run()
# -> del self._target, self._args, self._kwargs
# (Pdb) n
# --Return--
# > /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py(874)run()->None
# -> del self._target, self._args, self._kwargs
# (Pdb) n
# > /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py(967)_bootstrap_inner()
# -> pass
# (Pdb) n
# > /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py(969)_bootstrap_inner()
# -> with _active_limbo_lock:
# (Pdb) n
# > /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py(970)_bootstrap_inner()
# -> try:
# (Pdb) n
# > /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py(973)_bootstrap_inner()
# -> del _active[get_ident()]
# (Pdb) n
# --Return--
# > /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py(973)_bootstrap_inner()->None
# -> del _active[get_ident()]
# (Pdb) n
# --Return--
# > /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/threading.py(890)_bootstrap()->None
# -> self._bootstrap_inner()
# (Pdb) n
# --Call--
# > /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/zmq/sugar/socket.py(65)__del__()
# -> def __del__(self):
# (Pdb) n
# > /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/zmq/sugar/socket.py(66)__del__()
# -> if not self._shadow:
# (Pdb) n
# > /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/zmq/sugar/socket.py(67)__del__()
# -> self.close()
# (Pdb) n
# --Return--
# > /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/zmq/sugar/socket.py(67)__del__()->None
# -> self.close()
# (Pdb) n
