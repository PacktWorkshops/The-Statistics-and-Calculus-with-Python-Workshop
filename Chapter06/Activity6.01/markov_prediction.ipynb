# %% [markdown]
# ### Text prediction using Markov chain model

# %%
import numpy as np

# %%
churchill = open('churchill.txt').read()
keywords = churchill.split()
print(keywords)
# Out:
# ['The', 'position', 'of', 'the', 'B.', 'E.F', 'had', 'now', 'become', 'critical', 'As', 'a', 'result', 'of', 'a', 'most', 'skillfully', 'conducted', 'retreat', 'and', 'German', 'errors,', 'the', 'bulk', 'of', 'the', 'British', 'Forces', 'reached', 'the', 'Dunkirk', 'bridgehead.', 'The', 'peril', 'facing', 'the', 'British', 'nation', 'was', 'now', 'suddenly', 'and', 'universally', 'perceived.', 'On', 'May', '26,', '“Operation', 'Dynamo', '“–the', 'evacuation', 'from', 'Dunkirk', 'began.', 'The', 'seas', 'remained', 'absolutely', 'calm.', 'The', 'Royal', 'Air', 'Force–bitterly', 'maligned', 'at', 'the', 'time', 'by', 'the', 'Army–fought', 'vehemently', 'to', 'deny', 'the', 'enemy', 'the', 'total', 'air', 'supremacy', 'which', 'would', 'have', 'wrecked', 'the', 'operation.', 'At', 'the', 'outset,', 'it', 'was', 'hoped', 'that', '45,000', 'men', 'might', 'be', 'evacuated;', 'in', 'the', 'event,', 'over', '338,000', 'Allied', 'troops', 'reached', 'England,', 'including', '26,000', 'French
# ...

# %%
# Make state chart for follow-up words
keylist = []
for i in range(len(keywords)-1):
    keylist.append( (keywords[i], keywords[i+1]))
print(keylist)
# Out:
# [('The', 'position'), ('position', 'of'), ('of', 'the'), ('the', 'B.'), ('B.', 'E.F'), ('E.F', 'had'), ('had', 'now'), ('now', 'become'), ('become', 'critical'), ('critical', 'As'), ('As', 'a'), ('a', 'result'), ('result', 'of'), ('of', 'a'), ('a', 'most'), ('most', 'skillfully'), ('skillfully', 'conducted'), ('conducted', 'retreat'), ('retreat', 'and'), ('and', 'German'), ('German', 'errors,'), ('errors,', 'the'), ('the', 'bulk'), ('bulk', 'of'), ('of', 'the'), ('the', 'British'), ('British', 'Forces'), ('Forces', 'reached'), ('reached', 'the'), ('the', 'Dunkirk'), ('Dunkirk', 'bridgehead.'), ('bridgehead.', 'The'), ('The', 'peril'), ('peril', 'facing'), ('facing', 'the'), ('the', 'British'), ('British', 'nation'), ('nation', 'was'), ('was', 'now'), ('now', 'suddenly'), ('suddenly', 'and'), ('and', 'universally'), ('universally', 'perceived.'), ('perceived.', 'On'), ('On', 'May'), ('May', '26,'), ('26,', '“Operation'), ('“Operation', 'Dynamo'), ('Dynamo', '“–the'), ('“–the', 'evacua
# ...

# %%
# Create key-value pairs based on follow-up words
word_dict = {}
for beginning, following in keylist:
    if beginning in word_dict.keys():
        word_dict[beginning].append(following)
    else:
        word_dict[beginning] = [following]
print(word_dict)
# Out:
# {'The': ['position', 'peril', 'seas', 'Royal', 'French', 'Guards', 'Rifle', 'British', 'Belgian,', 'whole', 'King', 'surrender', 'enemy', 'numbers', 'hospital', 'enemy', 'Royal', 'great', 'Knights', 'President', 'best', 'French', 'whole', 'British'], 'position': ['of'], 'of': ['the', 'a', 'the', 'Commons,', 'national', 'the', 'May,', 'the', 'the', 'this', 'the', 'over', 'the', 'Belgium.', 'the', 'General', 'the', 'the', 'the', 'about', 'different', 'German', 'the', 'liberties', 'desperate', 'British', 'intense', 'a', 'their', 'the', 'Dunkirk', 'the', 'retreat', 'the', 'the', 'the', 'food', 'the', 'the', 'the', 'retreat', 'his', 'retreat.', 'the', 'the', 'Allied', 'their', 'hostile', 'which', 'the', 'them-together', 'infantry', 'countless', 'bombs', 'artillery', 'their', 'British', 'its', 'deliverance,', 'the', 'at', 'all', 'the', 'death', 'a', 'our', 'this;', 'my', 'strength', 'thousands?', 'greater', 'the', 'German', 'one-quarter', 'their', 'the', 'a', 'our', 'a', 'armored', 'civili
# ...

# %%
# Generate the first word and append to a list
first_word = np.random.choice(keywords)
while first_word.islower():
    first_word = np.random.choice(keywords)
word_chain = [first_word]

# %% [markdown]
# ### Generating first word from the dataset

# %%
print(word_chain)
# Out:
# ['German']

# %%
# Append new words based on Markov model to a list
WORDCOUNT = 40
for i in range(WORDCOUNT):
    word_chain.append(np.random.choice(word_dict[word_chain[-1]]))

# %% [markdown]
# ### Producing output

# %%
# Form a sentence from the list of words
sentence = ' '.join(word_chain)
print(sentence)
# Out:
# German bombers which lie immediately ahead. We have been given an ignominious and that the sympathy of the whole of the time more of malice, the main power, the slightest sympathy. Parliament and behind them always the British Armies might be
