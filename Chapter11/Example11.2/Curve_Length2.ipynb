# %%
from math import sqrt

def derivative(f,x):
    """Returns the value of the derivative of
    the function at a given x-value."""
    delta_x = 1/1000000
    return (f(x+delta_x) - f(x))/delta_x

def trap_integral(f,a,b,num):
    """Returns the sum of num trapezoids
    under f between a and b"""
    width = (b-a)/num
    area = 0.5*width*(f(a) + f(b) + 2*sum([f(a+width*n) \
                                        for n in range(num)]))
    return area

#Length of a curve:
#L = int sqrt(1+[f'(x)]**2)
def curve_length(f,a,b,num):
    def g(x):
        return sqrt(1+(derivative(f,x)**2))
    return trap_integral(g,a,b,num)

def f(x):
    return sqrt(1-x**2)

print(curve_length(f,-1,1,100))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-9875f8699eb9> in <module>
#      25     return sqrt(1-x**2)
#      26
# ---> 27 print(curve_length(f,-1,1,100))
#
# <ipython-input-1-9875f8699eb9> in curve_length(f, a, b, num)
#      20     def g(x):
#      21         return sqrt(1+(derivative(f,x)**2))
# ---> 22     return trap_integral(g,a,b,num)
#      23
#      24 def f(x):
#
# <ipython-input-1-9875f8699eb9> in trap_integral(f, a, b, num)
#      11     under f between a and b"""
#      12     width = (b-a)/num
# ---> 13     area = 0.5*width*(f(a) + f(b) + 2*sum([f(a+width*n) \
#      14                                         for n in range(num)]))
#      15     return area
#
# <ipython-input-1-9875f8699eb9> in g(x)
#      19 def curve_length(f,a,b,num):
#      20     def g(x):
# ---> 21         return sqrt(1+(derivative(f,x)**2))
#      22     return trap_integral(g,a,b,num)
#      23
#
# <ipython-input-1-9875f8699eb9> in derivative(f, x)
#       5     the function at a given x-value."""
#       6     delta_x = 1/1000000
# ----> 7     return (f(x+delta_x) - f(x))/delta_x
#       8
#       9 def trap_integral(f,a,b,num):
#
# <ipython-input-1-9875f8699eb9> in f(x)
#      23
#      24 def f(x):
# ---> 25     return sqrt(1-x**2)
#      26
#      27 print(curve_length(f,-1,1,100))
#
# ValueError: math domain error
